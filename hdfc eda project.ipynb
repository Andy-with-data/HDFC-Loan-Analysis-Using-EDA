# %% [markdown]
# #                 HDFC LOAN ANALYSIS

# %%
import pandas as pd

# %%
data=pd.read_csv(r'C:\\Users\\Aniket\\OneDrive\\Desktop\\hdfc loan process1.csv') # importing csv file into python

# %%
data       # printing the dataset
# Out:
#       id reagion        year  loan type                   loan    tenure  \
# 0      1   south  01-01-2019    secured              home loan  12 month
# 1      2    east  02-01-2019    secured  loan against property  24 month
# 2      3   north  03-01-2019    secured              gold loan  12 month
# 3      4    west  04-01-2019    secured              home loan  48 month
# 4      5   south  05-01-2019    secured              home loan  48 month
# ..   ...     ...         ...        ...                    ...       ...
# 295  296   north  26-09-2019  unsecured          business loan  48 month
# 296  297   north  27-09-2019  unsecured          business loan  12 month
# 297  298   north  28-09-2019  unsecured          personal loan  24 month
# 298  299    east  29-09-2019  unsecured          personal loan  12 month
# 299  300    east  30-09-2019  unsecured          personal loan  48 month
#
#        profit     city  age  gender  cibil score    sales default  \
# ...

# %% [markdown]
# # 1) head()

# %%
data.head()       # to show to top 5 records in dataset
# Out:
#    id reagion        year loan type                   loan    tenure  \
# 0   1   south  01-01-2019   secured              home loan  12 month
# 1   2    east  02-01-2019   secured  loan against property  24 month
# 2   3   north  03-01-2019   secured              gold loan  12 month
# 3   4    west  04-01-2019   secured              home loan  48 month
# 4   5   south  05-01-2019   secured              home loan  48 month
#
#      profit     city  age  gender  cibil score    sales default  \
# 0    23.360    kochi   22    male          780   36.369    yes
# 1   236.360  kolkata   25  female          723   52.259      no
# 2    56.369    delhi   28    male          753  369.200      no
# 3  4586.250   mumbai   30    male          789   24.360      no
# 4     5.269   mysuru   58    male          741   74.123    yes
#
#                 job
# 0  SOFTWARE DEVLOPER
# 1            TEACHER
# 2                 CA
# 3             LAWYER
# 4           DESIGNER

# %% [markdown]
# # 2) tail()

# %%
data.tail()       # to show top 5 bottom records in dataset
# Out:
#       id reagion        year  loan type           loan    tenure    profit  \
# 295  296   north  26-09-2019  unsecured  business loan  48 month    23.360
# 296  297   north  27-09-2019  unsecured  business loan  12 month   236.360
# 297  298   north  28-09-2019  unsecured  personal loan  24 month    56.369
# 298  299    east  29-09-2019  unsecured  personal loan  12 month  4586.250
# 299  300    east  30-09-2019  unsecured  personal loan  48 month     5.269
#
#         city  age gender  cibil score    sales default           job
# 295    delhi   45   male          710   36.690      no        TEACHER
# 296     agra   50   male          720   52.259      no             CA
# 297     agra   28   male          730  369.200      no     CONSULTANT
# 298  kolkata   25   male          740   24.360      no  HOTEL MANEGER
# 299    patna   30   male          750   74.123      no       ADVOCATE

# %% [markdown]
# # 3) shape()

# %%
data.shape       # to show total number of row nd columns
# Out:
# (300, 14)

# %% [markdown]
# # 4) size()

# %%
data.size       # to show total number of ele in  dataset
# Out:
# 4200

# %% [markdown]
# # 5) columns()

# %%
data.columns       # to show total columns in dataset
# Out:
# Index(['id', 'reagion', 'year', 'loan type', 'loan', 'tenure', 'profit',
#        'city', 'age', 'gender', 'cibil score', 'sales', 'default', 'job '],
#       dtype='object')

# %% [markdown]
# # 6)dtype()

# %%
data.dtypes       # to show datatypes of each columns
# Out:
# id               int64
# reagion         object
# year            object
# loan type       object
# loan            object
# tenure          object
# profit         float64
# city            object
# age              int64
# gender          object
# cibil score      int64
# sales          float64
# default         object
# job             object
# dtype: object

# %% [markdown]
# # 8) info()

# %%
data.info()       # to show index,columns,data types each column memeory at onces
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           300 non-null    int64
#  1   reagion      300 non-null    object
#  2   year         300 non-null    object
#  3   loan type    300 non-null    object
#  4   loan         300 non-null    object
#  5   tenure       300 non-null    object
#  6   profit       300 non-null    float64
#  7   city         299 non-null    object
#  8   age          300 non-null    int64
#  9   gender       300 non-null    object
#  10  cibil score  300 non-null    int64
#  11  sales        300 non-null    float64
#  12  default      300 non-null    object
#  13  job          300 non-null    object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 32.9+ KB

# %% [markdown]
# # Task 1:IS any duplicate value records present.IF yes then remove

# %% [markdown]
# # duplicate()

# %%
data.head()
# Out:
#    id reagion        year loan type                   loan    tenure  \
# 0   1   south  01-01-2019   secured              home loan  12 month
# 1   2    east  02-01-2019   secured  loan against property  24 month
# 2   3   north  03-01-2019   secured              gold loan  12 month
# 3   4    west  04-01-2019   secured              home loan  48 month
# 4   5   south  05-01-2019   secured              home loan  48 month
#
#      profit     city  age  gender  cibil score    sales default  \
# 0    23.360    kochi   22    male          780   36.369    yes
# 1   236.360  kolkata   25  female          723   52.259      no
# 2    56.369    delhi   28    male          753  369.200      no
# 3  4586.250   mumbai   30    male          789   24.360      no
# 4     5.269   mysuru   58    male          741   74.123    yes
#
#                 job
# 0  SOFTWARE DEVLOPER
# 1            TEACHER
# 2                 CA
# 3             LAWYER
# 4           DESIGNER

# %%
data[data.duplicated()]       # there is no any duplicate records
# Out:
# Empty DataFrame
# Columns: [id, reagion, year, loan type, loan, tenure, profit, city, age, gender, cibil score, sales, default, job ]
# Index: []

# %%
data.drop_duplicates(inplace=True)       # it will remove all duplicate records
# still this changes are permanant want to change inplace should be used

# %%
data.head()
# Out:
#    id reagion        year loan type                   loan    tenure  \
# 0   1   south  01-01-2019   secured              home loan  12 month
# 1   2    east  02-01-2019   secured  loan against property  24 month
# 2   3   north  03-01-2019   secured              gold loan  12 month
# 3   4    west  04-01-2019   secured              home loan  48 month
# 4   5   south  05-01-2019   secured              home loan  48 month
#
#      profit     city  age  gender  cibil score    sales default  \
# 0    23.360    kochi   22    male          780   36.369    yes
# 1   236.360  kolkata   25  female          723   52.259      no
# 2    56.369    delhi   28    male          753  369.200      no
# 3  4586.250   mumbai   30    male          789   24.360      no
# 4     5.269   mysuru   58    male          741   74.123    yes
#
#                 job
# 0  SOFTWARE DEVLOPER
# 1            TEACHER
# 2                 CA
# 3             LAWYER
# 4           DESIGNER

# %% [markdown]
# # task 2:IS there any null value.

# %% [markdown]
# #  isnull()

# %%
data.isnull()       # to show the null values
# Out:
#         id  reagion   year  loan type   loan  tenure  profit   city    age  \
# 0    False    False  False      False  False   False   False  False  False
# 1    False    False  False      False  False   False   False  False  False
# 2    False    False  False      False  False   False   False  False  False
# 3    False    False  False      False  False   False   False  False  False
# 4    False    False  False      False  False   False   False  False  False
# ..     ...      ...    ...        ...    ...     ...     ...    ...    ...
# 295  False    False  False      False  False   False   False  False  False
# 296  False    False  False      False  False   False   False  False  False
# 297  False    False  False      False  False   False   False  False  False
# 298  False    False  False      False  False   False   False  False  False
# 299  False    False  False      False  False   False   False  False  False
#
#      gender  cibil score  sales  default   job
# ...

# %%
data.isnull().sum()       # to show count of null values in each column
# Out:
# id             0
# reagion        0
# year           0
# loan type      0
# loan           0
# tenure         0
# profit         0
# city           1
# age            0
# gender         0
# cibil score    0
# sales          0
# default        0
# job            0
# dtype: int64

# %% [markdown]
# # seaborn lib (heat map)

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # To find any perticular record used isin() nd str.contains()

# %%
data.head()
# Out:
#    id reagion        year loan type                   loan    tenure  \
# 0   1   south  01-01-2019   secured              home loan  12 month
# 1   2    east  02-01-2019   secured  loan against property  24 month
# 2   3   north  03-01-2019   secured              gold loan  12 month
# 3   4    west  04-01-2019   secured              home loan  48 month
# 4   5   south  05-01-2019   secured              home loan  48 month
#
#      profit     city  age  gender  cibil score    sales default  \
# 0    23.360    kochi   22    male          780   36.369    yes
# 1   236.360  kolkata   25  female          723   52.259      no
# 2    56.369    delhi   28    male          753  369.200      no
# 3  4586.250   mumbai   30    male          789   24.360      no
# 4     5.269   mysuru   58    male          741   74.123    yes
#
#                 job
# 0  SOFTWARE DEVLOPER
# 1            TEACHER
# 2                 CA
# 3             LAWYER
# 4           DESIGNER

# %%
data[data['loan'].isin(['business loan'])]       # to find perticular element in column
# Out:
#       id reagion        year  loan type           loan    tenure     profit  \
# 141  142   north  26-11-2021  unsecured  business loan  12 month    23.3600
# 144  145   north  29-11-2021  unsecured  business loan  48 month  4586.2500
# 145  146   north  30-11-2021  unsecured  business loan  48 month     5.2690
# 146  147    east  01-12-2021  unsecured  business loan  48 month    48.3690
# 147  148    east  02-12-2021  unsecured  business loan  48 month   789.2500
# ..   ...     ...         ...        ...            ...       ...        ...
# 292  293    east  23-09-2019  unsecured  business loan  48 month     5.2690
# 293  294   north  24-09-2019  unsecured  business loan  48 month     1.2586
# 294  295   north  25-09-2019  unsecured  business loan  48 month    63.2150
# 295  296   north  26-09-2019  unsecured  business loan  48 month    23.3600
# 296  297   north  27-09-2019  unsecured  business loan  12 month   236.3600
#
# ...

# %%
data[data['loan'].str.contains('business loan')]
# Out:
#       id reagion        year  loan type           loan    tenure     profit  \
# 141  142   north  26-11-2021  unsecured  business loan  12 month    23.3600
# 144  145   north  29-11-2021  unsecured  business loan  48 month  4586.2500
# 145  146   north  30-11-2021  unsecured  business loan  48 month     5.2690
# 146  147    east  01-12-2021  unsecured  business loan  48 month    48.3690
# 147  148    east  02-12-2021  unsecured  business loan  48 month   789.2500
# ..   ...     ...         ...        ...            ...       ...        ...
# 292  293    east  23-09-2019  unsecured  business loan  48 month     5.2690
# 293  294   north  24-09-2019  unsecured  business loan  48 month     1.2586
# 294  295   north  25-09-2019  unsecured  business loan  48 month    63.2150
# 295  296   north  26-09-2019  unsecured  business loan  48 month    23.3600
# 296  297   north  27-09-2019  unsecured  business loan  12 month   236.3600
#
# ...

# %% [markdown]
# # In which year secured nd unsecured loan getting.show with bar graph

# %% [markdown]
# # dtype()

# %%
data.dtypes       # year is in object format need to convert it with date
# Out:
# id               int64
# reagion         object
# year            object
# loan type       object
# loan            object
# tenure          object
# profit         float64
# city            object
# age              int64
# gender          object
# cibil score      int64
# sales          float64
# default         object
# job             object
# dtype: object

# %% [markdown]
# # to_datetime()

# %%
data['Date_new']=pd.to_datetime(data['year'])
# Out:
# C:\Users\Aniket\AppData\Local\Temp\ipykernel_33280\1247825625.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['Date_new']=pd.to_datetime(data['year'])

# %%
data.head()
# Out:
#    id reagion        year loan type                   loan    tenure  \
# 0   1   south  01-01-2019   secured              home loan  12 month
# 1   2    east  02-01-2019   secured  loan against property  24 month
# 2   3   north  03-01-2019   secured              gold loan  12 month
# 3   4    west  04-01-2019   secured              home loan  48 month
# 4   5   south  05-01-2019   secured              home loan  48 month
#
#      profit     city  age  gender  cibil score    sales default  \
# 0    23.360    kochi   22    male          780   36.369    yes
# 1   236.360  kolkata   25  female          723   52.259      no
# 2    56.369    delhi   28    male          753  369.200      no
# 3  4586.250   mumbai   30    male          789   24.360      no
# 4     5.269   mysuru   58    male          741   74.123    yes
#
#                 job    Date_new
# 0  SOFTWARE DEVLOPER 2019-01-01
# 1            TEACHER 2019-02-01
# 2                 CA 2019-03-01
# 3             LAWYER 2019-04-01
# ...

# %%
data.dtypes
# Out:
# id                      int64
# reagion                object
# year                   object
# loan type              object
# loan                   object
# tenure                 object
# profit                float64
# city                   object
# age                     int64
# gender                 object
# cibil score             int64
# sales                 float64
# default                object
# job                    object
# Date_new       datetime64[ns]
# dtype: object

# %%
data['Date_new'].dt.year.value_counts()       # will count occurence of all individual year in date column
# Out:
# 2021    122
# 2022    107
# 2020     37
# 2019     34
# Name: Date_new, dtype: int64

# %% [markdown]
# #  Bar graph

# %%
data['Date_new'].dt.year.value_counts().plot(kind='bar',title='YEAR')
# Out:
# <Axes: title={'center': 'YEAR'}>

# %% [markdown]
# # How many male nd females are in the dataset?Show with bar graph

# %%
data.head(3)
# Out:
#    id reagion        year loan type                   loan    tenure   profit  \
# 0   1   south  01-01-2019   secured              home loan  12 month   23.360
# 1   2    east  02-01-2019   secured  loan against property  24 month  236.360
# 2   3   north  03-01-2019   secured              gold loan  12 month   56.369
#
#       city  age  gender  cibil score    sales default               job   \
# 0    kochi   22    male          780   36.369    yes   SOFTWARE DEVLOPER
# 1  kolkata   25  female          723   52.259      no            TEACHER
# 2    delhi   28    male          753  369.200      no                 CA
#
#     Date_new
# 0 2019-01-01
# 1 2019-02-01
# 2 2019-03-01

# %% [markdown]
# # groupby()

# %%
data.groupby('gender').gender.count()       #to group all unique items of column nd show their count
# Out:
# gender
# female    110
# male      190
# Name: gender, dtype: int64

# %% [markdown]
# # countplot()

# %%
data.groupby('gender').gender.count().plot(kind='bar',color='red')
# Out:
# <Axes: xlabel='gender'>

# %% [markdown]
# # to show all loans get in year 2021

# %% [markdown]
# creating new column

# %%
data.head()
# Out:
#    id reagion        year loan type                   loan    tenure  \
# 0   1   south  01-01-2019   secured              home loan  12 month
# 1   2    east  02-01-2019   secured  loan against property  24 month
# 2   3   north  03-01-2019   secured              gold loan  12 month
# 3   4    west  04-01-2019   secured              home loan  48 month
# 4   5   south  05-01-2019   secured              home loan  48 month
#
#      profit     city  age  gender  cibil score    sales default  \
# 0    23.360    kochi   22    male          780   36.369    yes
# 1   236.360  kolkata   25  female          723   52.259      no
# 2    56.369    delhi   28    male          753  369.200      no
# 3  4586.250   mumbai   30    male          789   24.360      no
# 4     5.269   mysuru   58    male          741   74.123    yes
#
#                 job    Date_new
# 0  SOFTWARE DEVLOPER 2019-01-01
# 1            TEACHER 2019-02-01
# 2                 CA 2019-03-01
# 3             LAWYER 2019-04-01
# ...

# %%
data['year']=data['Date_new'].dt.year

# %%
data.head()
# Out:
#    id reagion  year loan type                   loan    tenure    profit  \
# 0   1   south  2019   secured              home loan  12 month    23.360
# 1   2    east  2019   secured  loan against property  24 month   236.360
# 2   3   north  2019   secured              gold loan  12 month    56.369
# 3   4    west  2019   secured              home loan  48 month  4586.250
# 4   5   south  2019   secured              home loan  48 month     5.269
#
#       city  age  gender  cibil score    sales default               job   \
# 0    kochi   22    male          780   36.369    yes   SOFTWARE DEVLOPER
# 1  kolkata   25  female          723   52.259      no            TEACHER
# 2    delhi   28    male          753  369.200      no                 CA
# 3   mumbai   30    male          789   24.360      no             LAWYER
# 4   mysuru   58    male          741   74.123    yes            DESIGNER
#
#     Date_new
# 0 2019-01-01
# 1 2019-02-01
# 2 2019-03-01
# 3 2019-04-01
# 4 2019-05-01

# %% [markdown]
# # flitering

# %%
x=data[(data['loan']=='home loan') & (data['year']==2021)]

# %%
x
# Out:
#       id reagion  year loan type       loan    tenure     profit        city  \
# 102  103    east  2021   secured  home loan  48 month    63.2150     kolkata
# 103  104    east  2021   secured  home loan  48 month    23.3600       patna
# 104  105    east  2021   secured  home loan  48 month   236.3600      cuttak
# 105  106    east  2021   secured  home loan  12 month    56.3690        gaya
# 106  107    east  2021   secured  home loan  24 month  4586.2500       patna
# 107  108    east  2021   secured  home loan  12 month     5.2690        gaya
# 108  109   north  2021   secured  home loan  48 month     1.2586       delhi
# 109  110   north  2021   secured  home loan  48 month    63.2150        agra
# 110  111   north  2021   secured  home loan  48 month    23.3600      punjab
# 111  112   north  2021   secured  home loan  48 month   236.3600  chandigarh
# 112  113   north  2021   secured  home loan  48 month    56.3690         NaN
# ...

# %% [markdown]
# # show only west reagion whose cibil greater than 700

# %%
t=data[(data['reagion']=='west') & (data['cibil score']>700)]

# %%
t
# Out:
#       id reagion  year  loan type                   loan    tenure     profit  \
# 3      4    west  2019    secured              home loan  48 month  4586.2500
# 16    17    west  2019    secured              home loan  48 month  4586.2500
# 17    18    west  2019    secured              home loan  48 month     5.2690
# 18    19    west  2020    secured              home loan  48 month     1.2586
# 19    20    west  2020    secured              home loan  48 month    63.2150
# 20    21    west  2020    secured              home loan  48 month  4586.2500
# 21    22    west  2020    secured              home loan  48 month     5.2690
# 22    23    west  2020    secured              home loan  48 month     1.2586
# 23    24    west  2020    secured              home loan  48 month    63.2150
# 24    25    west  2020    secured              home loan  48 month  4586.2500
# 25    26    west  2020    secured              home loan  48 month     5.2690
# ...

# %%
t.shape
# Out:
# (30, 15)

# %% [markdown]
# # show top 10 cities who gave max loan

# %%
data['city'].value_counts().head(10)
# Out:
# patna       30
# gaya        24
# punjab      22
# banglore    20
# cuttak      19
# delhi       18
# surat       18
# kolkata     17
# madurai     16
# agra        16
# Name: city, dtype: int64

# %% [markdown]
# # show all records where loan type is secured nd reagion is south or city is pune

# %%
data.head(2)
# Out:
#    id reagion  year loan type                   loan    tenure  profit  \
# 0   1   south  2019   secured              home loan  12 month   23.36
# 1   2    east  2019   secured  loan against property  24 month  236.36
#
#       city  age  gender  cibil score   sales default               job   \
# 0    kochi   22    male          780  36.369    yes   SOFTWARE DEVLOPER
# 1  kolkata   25  female          723  52.259      no            TEACHER
#
#     Date_new
# 0 2019-01-01
# 1 2019-02-01

# %%
o=data[ (data['loan type']=='secured') & (data['reagion']=='south') ]

# %%
ok=data[ (data['loan type']=='secured') & (data['reagion']=='south') | (data['city']=='pune') ]

# %%
o.shape
# Out:
# (31, 15)

# %%
ok.shape
# Out:
# (47, 15)

# %% [markdown]
# # 48 month tenure reapeted how many time

# %%
data[data['tenure']=='48 month']
# Out:
#       id reagion  year  loan type           loan    tenure     profit    city  \
# 3      4    west  2019    secured      home loan  48 month  4586.2500  mumbai
# 4      5   south  2019    secured      home loan  48 month     5.2690  mysuru
# 5      6    west  2019    secured      home loan  48 month     1.2586    pune
# 6      7    west  2019    secured      home loan  48 month    63.2150  mumbai
# 7      8    west  2019    secured      home loan  48 month   236.3600  nagpur
# ..   ...     ...   ...        ...            ...       ...        ...     ...
# 292  293    east  2019  unsecured  business loan  48 month     5.2690  cuttak
# 293  294   north  2019  unsecured  business loan  48 month     1.2586   delhi
# 294  295   north  2019  unsecured  business loan  48 month    63.2150    agra
# 295  296   north  2019  unsecured  business loan  48 month    23.3600   delhi
# 299  300    east  2019  unsecured  personal loan  48 month     5.2690   patna
#
# ...

# %%
c=data[data['tenure']=='48 month']

# %%
c
# Out:
#       id reagion  year  loan type           loan    tenure     profit    city  \
# 3      4    west  2019    secured      home loan  48 month  4586.2500  mumbai
# 4      5   south  2019    secured      home loan  48 month     5.2690  mysuru
# 5      6    west  2019    secured      home loan  48 month     1.2586    pune
# 6      7    west  2019    secured      home loan  48 month    63.2150  mumbai
# 7      8    west  2019    secured      home loan  48 month   236.3600  nagpur
# ..   ...     ...   ...        ...            ...       ...        ...     ...
# 292  293    east  2019  unsecured  business loan  48 month     5.2690  cuttak
# 293  294   north  2019  unsecured  business loan  48 month     1.2586   delhi
# 294  295   north  2019  unsecured  business loan  48 month    63.2150    agra
# 295  296   north  2019  unsecured  business loan  48 month    23.3600   delhi
# 299  300    east  2019  unsecured  personal loan  48 month     5.2690   patna
#
# ...

# %%
c.tenure
# Out:
# 3      48 month
# 4      48 month
# 5      48 month
# 6      48 month
# 7      48 month
#          ...
# 292    48 month
# 293    48 month
# 294    48 month
# 295    48 month
# 299    48 month
# Name: tenure, Length: 252, dtype: object

# %%
data.city.nunique()
# Out:
# 21

# %%
data.age.unique()
# Out:
# array([22, 25, 28, 30, 58, 45, 36, 50, 52, 59, 35, 60], dtype=int64)

# %%
data.age.nunique()       # to find unique records in data frame
# Out:
# 12

# %%
data.city.unique()
# Out:
# array(['kochi', 'kolkata', 'delhi', 'mumbai', 'mysuru', 'pune', 'nagpur',
#        'nashik', 'ahemdabad', 'banglore', 'madurai', 'chennai', 'patna',
#        'cuttak', 'gaya', 'agra', 'punjab', 'chandigarh', 'varanasi',
#        'surat', 'vadodara', nan], dtype=object)
